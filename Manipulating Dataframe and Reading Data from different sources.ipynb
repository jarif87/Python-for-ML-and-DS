# %%
import pandas as pd

# %%
data=pd.read_csv("/work/Iris.csv")

# %%
data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # create new data

# %%
data["New Data"]=data["SepalLengthCm"]/data["PetalLengthCm"]**3

# %%
data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    New Data
# 0  1.858601
# 1  1.785714
# 2  2.139281
# 3  1.362963
# 4  1.822157

# %% [markdown]
# # copy data to new variable

# %%
new_data=data.copy()

# %%
new_data.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5  10            6.0           5.0            4.0           5.0     new_data
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
#
#    New Data
# 0  1.858601
# 1  1.785714
# 2  2.139281
# 3  1.362963
# 4  1.822157
# 5  4.222220
# 6  1.676385
# 7  1.481481
# ...

# %% [markdown]
# # replace data with new data

# %%
new_data.loc[5]=[10,6,5,4,5,"new_data",4.22222]

# %%
new_data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    New Data
# 0  1.858601
# 1  1.785714
# 2  2.139281
# 3  1.362963
# 4  1.822157

# %%
new_data.iloc[5]
# Out:
# Id                     10
# SepalLengthCm         6.0
# SepalWidthCm          5.0
# PetalLengthCm         4.0
# PetalWidthCm          5.0
# Species          new_data
# New Data          4.22222
# Name: 5, dtype: object

# %% [markdown]
# # access data with index location(iloc)

# %%
new_data.iloc[6 : 15]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
#
#     New Data
# 6   1.676385
# 7   1.481481
# 8   1.603499
# 9   1.451852
# 10  1.600000
# 11  1.171875
# 12  1.749271
# 13  3.230654
# 14  3.356481

# %% [markdown]
# # access first column

# %%
new_data.iloc[:,1]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
new_data.iloc[ 0 : 10, :] #observation,columns
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5  10            6.0           5.0            4.0           5.0     new_data
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
#
#    New Data
# 0  1.858601
# 1  1.785714
# 2  2.139281
# 3  1.362963
# 4  1.822157
# 5  4.222220
# 6  1.676385
# 7  1.481481
# ...

# %%
new_data.iloc[ 0 : 10, : 4] #observation,columns
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0   1            5.1           3.5            1.4
# 1   2            4.9           3.0            1.4
# 2   3            4.7           3.2            1.3
# 3   4            4.6           3.1            1.5
# 4   5            5.0           3.6            1.4
# 5  10            6.0           5.0            4.0
# 6   7            4.6           3.4            1.4
# 7   8            5.0           3.4            1.5
# 8   9            4.4           2.9            1.4
# 9  10            4.9           3.1            1.5

# %%
new_data.sort_values("SepalLengthCm")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species  New Data
# 13      Iris-setosa  3.230654
# 42      Iris-setosa  2.002731
# 38      Iris-setosa  2.002731
# 8       Iris-setosa  1.603499
# ...

# %%
new_data.sort_values("Id",ascending=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 149  150            5.9           3.0            5.1           1.8
# 148  149            6.2           3.4            5.4           2.3
# 147  148            6.5           3.0            5.2           2.0
# 146  147            6.3           2.5            5.0           1.9
# 145  146            6.7           3.0            5.2           2.3
# ..   ...            ...           ...            ...           ...
# 4      5            5.0           3.6            1.4           0.2
# 3      4            4.6           3.1            1.5           0.2
# 2      3            4.7           3.2            1.3           0.2
# 1      2            4.9           3.0            1.4           0.2
# 0      1            5.1           3.5            1.4           0.2
#
#             Species  New Data
# 149  Iris-virginica  0.044478
# 148  Iris-virginica  0.039374
# 147  Iris-virginica  0.046228
# 146  Iris-virginica  0.050400
# ...

# %%
new_data["New Data_Rank"]=data["New Data"].rank(ascending=True,method="min")

# %%
new_data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    New Data  New Data_Rank
# 0  1.858601          136.0
# 1  1.785714          133.0
# 2  2.139281          143.0
# 3  1.362963          114.0
# 4  1.822157          134.0

# %%
# data["New Data_Rank"]=data["New Data"].rank(ascending=True,method="dense")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=71c4a58e-b573-4d3f-9623-0d8de0f593fa' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
