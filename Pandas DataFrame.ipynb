# %%
import pandas as pd

# %%
data=[10,20,30,40,50]

# %%
subject=["bangla","english","math","physics","chemistry"]

# %%
pd_ser=pd.Series(data,index=subject)

# %%
pd_ser
# Out:
# bangla       10
# english      20
# math         30
# physics      40
# chemistry    50
# dtype: int64

# %%
data={"subject":["bangla","english","math","physics","chemistry"],"marks":[10,20,30,40,50],"cgpa":[2,3,4,2.22,3.50]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      subject  marks  cgpa
# 0     bangla     10  2.00
# 1    english     20  3.00
# 2       math     30  4.00
# 3    physics     40  2.22
# 4  chemistry     50  3.50

# %%
sub=pd.Series(["bangla","englsh","math"])

# %%
mark=pd.Series([20,30,50])

# %%
cgpa=pd.Series([2.55,3.45,3.56])

# %%
df2=pd.DataFrame([sub,mark,cgpa],index=["subject","mark","cgpa"])

# %%
df2
# Out:
#               0       1     2
# subject  bangla  englsh  math
# mark         20      30    50
# cgpa       2.55    3.45  3.56

# %% [markdown]
# # Transpose

# %%
df3=pd.DataFrame([sub,mark,cgpa],index=["subject","mark","cgpa"]).T

# %%
df3
# Out:
#   subject mark  cgpa
# 0  bangla   20  2.55
# 1  englsh   30  3.45
# 2    math   50  3.56

# %%
iris=pd.read_csv("/work/Iris.csv")

# %%
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aabe3cc5-4837-4c1f-a2c0-1ad17e694010' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
